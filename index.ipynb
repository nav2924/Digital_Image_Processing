# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib

# %%
matplotlib.use('TkAgg')

# %%
model = YOLO("yolov8n.yaml")

# %%
results = model.train(
    data="config.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    save=True  
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.65 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.62  Python-3.11.0 torch-2.5.1+cpu CPU (AMD Ryzen 7 6800H with Radeon Graphics)
# ...

# %%
results_csv_path = "runs/detect/train2/results.csv"

# %%
results_df = pd.read_csv(results_csv_path)

mAP_column = "metrics/mAP50(B)"  # For mAP@50
mAP95_column = "metrics/mAP50-95(B)"  # For mAP@50:95

best_epoch_mAP50 = results_df[mAP_column].idxmax()
best_epoch_mAP95 = results_df[mAP95_column].idxmax()

print(f"Best Epoch (mAP@50): {best_epoch_mAP50}")
print(f"Best Epoch (mAP@50-95): {best_epoch_mAP95}")
    
print("\nMetrics for Best Epoch (mAP@50):")
print(results_df.iloc[best_epoch_mAP50])
# Out:
# Best Epoch (mAP@50): 77
# Best Epoch (mAP@50-95): 77
#
# Metrics for Best Epoch (mAP@50):
# epoch                     78.000000
# time                    2286.210000
# train/box_loss             1.902290
# train/cls_loss             2.944550
# train/dfl_loss             2.568870
# metrics/precision(B)       0.524150
# metrics/recall(B)          0.233940
# metrics/mAP50(B)           0.244450
# metrics/mAP50-95(B)        0.082820
# val/box_loss               2.286190
# val/cls_loss               3.361420
# val/dfl_loss               3.163560
# lr/pg0                     0.000264
# lr/pg1                     0.000264
# lr/pg2                     0.000264
# Name: 77, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.plot(results_df.index, results_df[mAP_column], label="mAP@50", marker='o')
plt.plot(results_df.index, results_df[mAP95_column], label="mAP@50-95", marker='x')
plt.xlabel("Epoch")
plt.ylabel("Metric Value")
plt.title("mAP Metrics Across Epochs")
plt.legend()
plt.grid()
plt.show()
plt.savefig("mAP_metrics.png")
print("Plot saved as 'mAP_metrics.png'")
# Out:
# Plot saved as 'mAP_metrics.png'
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
